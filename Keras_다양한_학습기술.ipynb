# %% [markdown]
# <a href="https://colab.research.google.com/github/ilmechaJu/keras/blob/main/Keras_%EB%8B%A4%EC%96%91%ED%95%9C_%ED%95%99%EC%8A%B5%EA%B8%B0%EC%88%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 케라스 다양한 학습 기술
#
# - 과대적합, 과소적합을 막기 위한 방법들
#   - 모델의 크기 축소
#
#   - 초기화
#
#   - 옵티마이저
#
#   - 배치 정규화
#
#   - 규제화

# %% [markdown]
# ### 모델의 크기 축소
# - 가장 단순한 방법
#
# - 모델의 크기를 줄인다는 것은 **학습 파라미터의 수를 줄이는 것**

# %% [markdown]
# #### 데이터 준비
# - 설명을 위한 코드

# %%
from tensorflow.keras.datasets import imdb
import numpy as np

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words = 10000)

def vectorize_seq(seqs, dim=10000):
  results = np.zeros((len(seqs), dim))
  for i, seq in enumerate(seqs):
    results[i, seq] = 1. #특정 index에 대해서만 1.0으로 만듦!

  return results

x_train = vectorize_seq(train_data)
x_test = vectorize_seq(test_data)

y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:155: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %% [markdown]
# #### 2가지의 모델 설정

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model_1 = Sequential([Dense(16, activation='relu', input_shape=(10000,), name = 'input'),
                      Dense(16, activation='relu', name='hidden'),
                      Dense(1, activation='sigmoid', name='output')])

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 16)                160016
# _________________________________________________________________
# hidden (Dense)               (None, 16)                272
# _________________________________________________________________
# output (Dense)               (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2 = Sequential([Dense(7, activation='relu', input_shape=(10000,), name='input'),
                      Dense(7, activation='relu', name='hidden'),
                      Dense(1, activation='sigmoid', name='output')])

# %%
model_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (Dense)                (None, 8)                 80008
# _________________________________________________________________
# hidden (Dense)               (None, 8)                 72
# _________________________________________________________________
# output (Dense)               (None, 1)                 9
# =================================================================
# Total params: 80,089
# Trainable params: 80,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_1.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['acc'])
model_2.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['acc'])

# %% [markdown]
# #### 2개의 모델 학습

# %%
model_1_hist = model_1.fit(x_train, y_train,
                           epochs=20,
                           batch_size=512,
                           validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 2s 34ms/step - loss: 0.4704 - acc: 0.8208 - val_loss: 0.3510 - val_acc: 0.8782
# Epoch 2/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.2708 - acc: 0.9065 - val_loss: 0.2873 - val_acc: 0.8896
# Epoch 3/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.2070 - acc: 0.9275 - val_loss: 0.2925 - val_acc: 0.8816
# Epoch 4/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1705 - acc: 0.9399 - val_loss: 0.2901 - val_acc: 0.8839
# Epoch 5/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1467 - acc: 0.9484 - val_loss: 0.3021 - val_acc: 0.8832
# Epoch 6/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1282 - acc: 0.9561 - val_loss: 0.3276 - val_acc: 0.8761
# Epoch 7/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.1122 - acc: 0.9600 - val_loss: 0.3443 - val_acc: 0.8738
# Epoch 8/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0976 - acc: 0.9672 - val_loss: 0.3830 - val_acc: 0.8689
# Epoch 9/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0836 - acc: 0.9735 - val_loss: 0.4065 - val_acc: 0.8652
# Epoch 10/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0752 - acc: 0.9766 - val_loss: 0.4265 - val_acc: 0.8658
# Epoch 11/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0650 - acc: 0.9800 - val_loss: 0.4530 - val_acc: 0.8633
# Epoch 12/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0553 - acc: 0.9843 - val_loss: 0.4854 - val_acc: 0.8618
# Epoch 13/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0472 - acc: 0.9866 - val_loss: 0.5179 - val_acc: 0.8611
# Epoch 14/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0391 - acc: 0.9896 - val_loss: 0.5522 - val_acc: 0.8584
# Epoch 15/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0333 - acc: 0.9913 - val_loss: 0.5924 - val_acc: 0.8575
# Epoch 16/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0274 - acc: 0.9932 - val_loss: 0.6629 - val_acc: 0.8510
# Epoch 17/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0233 - acc: 0.9941 - val_loss: 0.6756 - val_acc: 0.8528
# Epoch 18/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0176 - acc: 0.9964 - val_loss: 0.7410 - val_acc: 0.8523
# Epoch 19/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0148 - acc: 0.9968 - val_loss: 0.7770 - val_acc: 0.8488
# Epoch 20/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0125 - acc: 0.9975 - val_loss: 0.8116 - val_acc: 0.8519

# %%
model_2_hist = model_2.fit(x_train, y_train,
                           epochs=20,
                           batch_size=512,
                           validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 2s 38ms/step - loss: 0.5155 - acc: 0.8142 - val_loss: 0.4088 - val_acc: 0.8658
# Epoch 2/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.3173 - acc: 0.8998 - val_loss: 0.3126 - val_acc: 0.8858
# Epoch 3/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.2372 - acc: 0.9204 - val_loss: 0.2856 - val_acc: 0.8886
# Epoch 4/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1978 - acc: 0.9299 - val_loss: 0.2813 - val_acc: 0.8883
# Epoch 5/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1713 - acc: 0.9400 - val_loss: 0.2845 - val_acc: 0.8872
# Epoch 6/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1523 - acc: 0.9474 - val_loss: 0.2938 - val_acc: 0.8848
# Epoch 7/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1365 - acc: 0.9536 - val_loss: 0.3072 - val_acc: 0.8814
# Epoch 8/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1228 - acc: 0.9596 - val_loss: 0.3248 - val_acc: 0.8790
# Epoch 9/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1134 - acc: 0.9623 - val_loss: 0.3421 - val_acc: 0.8753
# Epoch 10/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1023 - acc: 0.9670 - val_loss: 0.3632 - val_acc: 0.8716
# Epoch 11/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0954 - acc: 0.9695 - val_loss: 0.3824 - val_acc: 0.8698
# Epoch 12/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0867 - acc: 0.9737 - val_loss: 0.4003 - val_acc: 0.8697
# Epoch 13/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0799 - acc: 0.9753 - val_loss: 0.4369 - val_acc: 0.8618
# Epoch 14/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0737 - acc: 0.9774 - val_loss: 0.4799 - val_acc: 0.8562
# Epoch 15/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0670 - acc: 0.9810 - val_loss: 0.4843 - val_acc: 0.8581
# Epoch 16/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0622 - acc: 0.9821 - val_loss: 0.5031 - val_acc: 0.8576
# Epoch 17/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0578 - acc: 0.9837 - val_loss: 0.5258 - val_acc: 0.8592
# Epoch 18/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0523 - acc: 0.9862 - val_loss: 0.5543 - val_acc: 0.8546
# Epoch 19/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0474 - acc: 0.9877 - val_loss: 0.5870 - val_acc: 0.8521
# Epoch 20/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0433 - acc: 0.9890 - val_loss: 0.6137 - val_acc: 0.8537

# %% [markdown]
# #### 비교

# %%
epochs = range(1, 21)
model_1_val_loss = model_1_hist.history['val_loss']
model_2_val_loss = model_2_hist.history['val_loss']

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

# %% [markdown]
# model_2 (더 작은 모델)이 '조금 더 나중에' 과대적합 발생

# %%
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, model_2_val_loss, 'bo', label='Model 2')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# ### 모델의 크기 축소 (2)

# %% [markdown]
# #### 모델 구성

# %%
model_3 = Sequential([Dense(1024, activation='relu', input_shape=(10000, ), name='input3'),
                      Dense(1024, activation='relu', name='hidden3'),
                      Dense(1, activation='sigmoid', name='output3')])

model_3.compile(optimizer='rmsprop',
                loss='binary_crossentropy',
                metrics=['acc'])

model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input3 (Dense)               (None, 1024)              10241024
# _________________________________________________________________
# hidden3 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# output3 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 11,291,649
# Trainable params: 11,291,649
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 모델 학습
# - 시간 소요

# %%
model_3_hist = model_3.fit(x_train, y_train,
                           epochs=20,
                           batch_size=512,
                           validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 3s 52ms/step - loss: 0.5046 - acc: 0.7886 - val_loss: 0.3314 - val_acc: 0.8556
# Epoch 2/20
# 49/49 [==============================] - 1s 30ms/step - loss: 0.2341 - acc: 0.9095 - val_loss: 0.3322 - val_acc: 0.8656
# Epoch 3/20
# 49/49 [==============================] - 1s 31ms/step - loss: 0.1259 - acc: 0.9546 - val_loss: 0.3608 - val_acc: 0.8764
# Epoch 4/20
# 49/49 [==============================] - 2s 31ms/step - loss: 0.0482 - acc: 0.9846 - val_loss: 0.4668 - val_acc: 0.8834
# Epoch 5/20
# 49/49 [==============================] - 2s 32ms/step - loss: 0.1316 - acc: 0.9844 - val_loss: 0.4566 - val_acc: 0.8812
# Epoch 6/20
# 49/49 [==============================] - 1s 31ms/step - loss: 8.2149e-04 - acc: 1.0000 - val_loss: 0.6780 - val_acc: 0.8835
# Epoch 7/20
# 49/49 [==============================] - 2s 31ms/step - loss: 4.8237e-05 - acc: 1.0000 - val_loss: 0.8384 - val_acc: 0.8825
# Epoch 8/20
# 49/49 [==============================] - 2s 32ms/step - loss: 4.3904e-06 - acc: 1.0000 - val_loss: 0.9945 - val_acc: 0.8822
# Epoch 9/20
# 49/49 [==============================] - 1s 31ms/step - loss: 5.8418e-07 - acc: 1.0000 - val_loss: 1.1205 - val_acc: 0.8826
# Epoch 10/20
# 49/49 [==============================] - 2s 31ms/step - loss: 9.2568e-08 - acc: 1.0000 - val_loss: 1.2417 - val_acc: 0.8830
# Epoch 11/20
# 49/49 [==============================] - 2s 31ms/step - loss: 2.7540e-08 - acc: 1.0000 - val_loss: 1.3137 - val_acc: 0.8832
# Epoch 12/20
# 49/49 [==============================] - 2s 31ms/step - loss: 1.4266e-08 - acc: 1.0000 - val_loss: 1.3524 - val_acc: 0.8831
# Epoch 13/20
# 49/49 [==============================] - 2s 31ms/step - loss: 9.5666e-09 - acc: 1.0000 - val_loss: 1.3781 - val_acc: 0.8830
# Epoch 14/20
# 49/49 [==============================] - 2s 31ms/step - loss: 7.2190e-09 - acc: 1.0000 - val_loss: 1.3974 - val_acc: 0.8831
# Epoch 15/20
# 49/49 [==============================] - 2s 31ms/step - loss: 5.8271e-09 - acc: 1.0000 - val_loss: 1.4112 - val_acc: 0.8832
# Epoch 16/20
# 49/49 [==============================] - 2s 31ms/step - loss: 4.8801e-09 - acc: 1.0000 - val_loss: 1.4249 - val_acc: 0.8830
# Epoch 17/20
# 49/49 [==============================] - 2s 31ms/step - loss: 4.2235e-09 - acc: 1.0000 - val_loss: 1.4348 - val_acc: 0.8830
# Epoch 18/20
# 49/49 [==============================] - 2s 31ms/step - loss: 3.7170e-09 - acc: 1.0000 - val_loss: 1.4435 - val_acc: 0.8830
# Epoch 19/20
# 49/49 [==============================] - 2s 32ms/step - loss: 3.3335e-09 - acc: 1.0000 - val_loss: 1.4529 - val_acc: 0.8831
# Epoch 20/20
# 49/49 [==============================] - 1s 30ms/step - loss: 3.0433e-09 - acc: 1.0000 - val_loss: 1.4594 - val_acc: 0.8831

# %% [markdown]
# #### 시각화

# %%
model_3_val_loss = model_3_hist.history['val_loss']

# %%
plt.plot(epochs, model_1_val_loss, 'r+', label='Model1')
plt.plot(epochs, model_2_val_loss, 'bo', label='Model2')
plt.plot(epochs, model_3_val_loss, 'g--', label='Model3')

plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

# %% [markdown]
# * 볼륨이 큰 신경망일수록 빠르게 훈련데이터 모델링 가능(학습 손실이 낮아짐)
# * 과대 적합에는 더욱 민감해짐
# * 이는 학습-검증 데이터의 손실을 보면 알 수 있음

# %%
model_1_train_loss = model_1_hist.history['loss']
model_2_train_loss = model_2_hist.history['loss']
model_3_train_loss = model_3_hist.history['loss']

plt.plot(epochs, model_1_val_loss, 'r+', label='Model1')
plt.plot(epochs, model_2_val_loss, 'bo', label='Model2')
plt.plot(epochs, model_3_val_loss, 'g--', label='Model3')

plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.legend()
plt.grid()

# %% [markdown]
# ### 가중치 초기화

# %% [markdown]
# #### 초기화 전략
#
# - Glorot Initialization (Xavier)
#   - 활성화 함수
#     - 없음
#     - tanh
#     - sigmoid
#     - softmax
#
# - He Initialization
#   - 활성화 함수
#     - ReLU
#     - LeakyReLU
#     - ELU 등

# %%
from tensorflow.keras.layers import Dense, LeakyReLU, Activation
from tensorflow.keras.models import Sequential

# %%
model = Sequential([Dense(30, kernel_initializer='he_normal', input_shape=[10,10]),
                    LeakyReLU(alpha=0.2),
                    Dense(1, kernel_initializer='he_normal'),
                    Activation("softmax")])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10, 30)            330
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 10, 30)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10, 1)             31
# _________________________________________________________________
# activation (Activation)      (None, 10, 1)             0
# =================================================================
# Total params: 361
# Trainable params: 361
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 고속 옵티마이저

# %% [markdown]
# #### 모멘텀 최적화
#
# $
# \qquad v \ \leftarrow \ \alpha \ v - \gamma \ \frac{\partial L}{\partial W} \\
# \qquad W \ \leftarrow \ W \ + \ v
# $
#
#   - $\alpha\ $ : 관성계수
#
#   - $v$ :  속도
#
#   - $\gamma\ $ : 학습률
#
#   - $\frac{\partial L}{\partial W}\ $ : 손실함수에 대한 미분

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import SGD

# %%
optimizer = SGD(learning_rate=0.001, momentum=0.9)

# %% [markdown]
# #### 네스테로프 (Nesterov)
#
# - 모멘텀의 방향으로 조금 앞선 곳에서 손실함수의 그라디언트를 구함
#
# - 시간이 지날수록 조금 더 빨리 최솟값에 도달
#
# $
# \qquad m \ \leftarrow \  \beta m - \eta \bigtriangledown_\theta J(\theta + \beta m) \\
# \qquad \theta \ \leftarrow \ \theta \ + m
# $
#
#
#   - $h\ $ : 기존 기울기를 제곱하여 더한 값
#
#   - $\eta\ $ : 학습률
#
#   - $\bigtriangledown_\theta J(\theta) \ $ : $\theta$에 대한 미분(그라디언트)
#
#   <img src="https://t1.daumcdn.net/cfile/tistory/99D91C455C76428D11">
#
#   <sub>출처: CS231n</sub>

# %%
optimizer = SGD(learning_rate=0.001, momentum=0.9, nesterov=True)

# %% [markdown]
# #### AdaGrad
#
# - 보통 간단한 모델에는 효과 좋을 수는 있으나, 심층 신경망 모델에서는 사용 X
#
# $
# \qquad h \ \leftarrow \  h + \frac{\partial L}{\partial W} \odot \frac{\partial L}{\partial W} \\
# \qquad W \ \leftarrow \ W \ + \gamma \frac{1}{\sqrt h} \ \frac{\partial L}{\partial W}
# $
#
#   - $h\ $ : 기존 기울기를 제곱하여 더한 값
#
#   - $\gamma\ $ : 학습률
#
#   - $\frac{\partial L}{\partial W}\ $ : $W$에 대한 미분

# %%
from tensorflow.keras.optimizers import Adagrad

# %%
optimizer = Adagrad(learning_rate=0.001)

# %% [markdown]
# #### RMSProp
#
#
# $
# \qquad s \ \leftarrow \ \beta \ s + (1 - \beta) \bigtriangledown_{\theta} J(\theta) \otimes \bigtriangledown_{\theta} J(\theta) \\
# \qquad \theta \ \leftarrow \ \theta \ - \eta  \ \bigtriangledown_{\theta} J(\theta) \oslash \sqrt{s + \epsilon}
# $
#
#   - $s \ $ : 그래디언트의 제곱을 감쇠율을 곱한 후 더함
#
#   - $\eta\ $ : 학습률
#
#   - $\bigtriangledown_{\theta} J(\theta) \ $ : 손실함수의 미분값

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
optimizer = RMSprop(learning_rate=0.001, rho=0.9)

# %% [markdown]
# #### Adam
#
# $
# \qquad m \ \leftarrow \  \beta_1 \ m - (1 - \beta_1)\ \frac{\partial L}{\partial W}  \\
# \qquad s \ \leftarrow \ \beta_2 \ s + (1 - \beta_2) \frac{\partial L}{\partial W} \odot \frac{\partial L}{\partial W} \\
# \qquad \hat{m} \ \leftarrow \frac{m}{1 - \beta_1^t} \\
# \qquad \hat{s} \ \leftarrow \frac{s}{1 - \beta_2^t} \\
# \qquad W \ \leftarrow \ W \ + \gamma \ \hat{m}\  \oslash \sqrt{\hat{s} + \epsilon}
# $
#
#   - $\beta\ $ : 지수 평균의 업데이트 계수
#
#   - $\gamma\ $ : 학습률
#
#   - $\beta_1 \approx 0.9\ ,\ \ \beta_2 \approx 0.999$
#
#   - $\frac{\partial L}{\partial W}\ $ : $W$에 대한 미분

# %%
from tensorflow.keras.optimizers import Adam

# %%
optimizer = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

# %% [markdown]
# ### 배치 정규화
# - 모델에 주입되는 샘플들을 균일하게 만드는 방법
#
# - 학습 후 새로운 데이터에 잘 일반화 할 수 있도록 도와줌
#
# - 데이터 전처리 단계에서 진행해도 되지만 정규화가 되어서 layer에 들어갔다는 보장이 없음
#
# - 주로 **Dense** 또는 **Conv2D** Layer 후, **활성화 함수**이전에 놓임

# %%
from tensorflow.keras.layers import BatchNormalization, Dense, Activation
from tensorflow.keras.utils import plot_model

# %%
model = Sequential()

model.add(Dense(32, input_shape=(28*28,), kernel_initializer='he_normal'))
model.add(BatchNormalization()) #dense와 activation 사이에 끼워서 generalization 잘되게 해줌.
model.add(Activation('relu'))

model.summary()

plot_model(model, show_shapes=True)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                25120
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32)                128
# _________________________________________________________________
# activation_2 (Activation)    (None, 32)                0
# =================================================================
# Total params: 25,248
# Trainable params: 25,184
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# ### 규제화
# - 복잡한 네트워크 일수록 네트워크의 복잡도에 제한을 두어
#   가중치가 작은 값을 가지도록 함
#
# - 가중치의 분포가 더 균일하게 됨
#
# - 네트워크 손실함수에 큰 가중치에 연관된 비용을 추가
#   - L1 규제 : 가중치의 절댓값에 비례하는 비용이 추가
#   - L2 규제 : 가중치의 제곱에 비례하는 비용이 추가(흔히 가중치 감쇠라고도 불림)
#   - 위 2규제가 합쳐진 경우도 존재

# %% [markdown]
# 데이터는 **모델의 크기** 파트에서 사용된 imdb dataset

# %%
from tensorflow.keras.regularizers import l1,l2,l1_l2

# %% [markdown]
# #### 모델 구성

# %%
l2_model = Sequential([Dense(16, kernel_regularizer=l2(0.001), activation='relu', input_shape=(10000, )),
                       Dense(16, kernel_regularizer=l2(0.001), activation='relu'),
                       Dense(1, activation='sigmoid')])

l2_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['acc'])

l2_model.summary()
plot_model(l2_model, show_shapes=True)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 16)                160016
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 모델 학습

# %%
#튀는거(=overfitting) 잡아줌
l2_model_hist = l2_model.fit(x_train, y_train,
                             epochs=20,
                             batch_size=512,
                             validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 3s 53ms/step - loss: 0.5180 - acc: 0.8176 - val_loss: 0.4042 - val_acc: 0.8758
# Epoch 2/20
# 49/49 [==============================] - 1s 25ms/step - loss: 0.3355 - acc: 0.9010 - val_loss: 0.3443 - val_acc: 0.8867
# Epoch 3/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2845 - acc: 0.9163 - val_loss: 0.3306 - val_acc: 0.8892
# Epoch 4/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2592 - acc: 0.9260 - val_loss: 0.3406 - val_acc: 0.8816
# Epoch 5/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2477 - acc: 0.9309 - val_loss: 0.3385 - val_acc: 0.8836
# Epoch 6/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2353 - acc: 0.9350 - val_loss: 0.3512 - val_acc: 0.8802
# Epoch 7/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2309 - acc: 0.9373 - val_loss: 0.3602 - val_acc: 0.8767
# Epoch 8/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2229 - acc: 0.9394 - val_loss: 0.3561 - val_acc: 0.8790
# Epoch 9/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2217 - acc: 0.9391 - val_loss: 0.3643 - val_acc: 0.8772
# Epoch 10/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.2131 - acc: 0.9450 - val_loss: 0.4026 - val_acc: 0.8646
# Epoch 11/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.2119 - acc: 0.9427 - val_loss: 0.3816 - val_acc: 0.8728
# Epoch 12/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.2089 - acc: 0.9452 - val_loss: 0.3812 - val_acc: 0.8735
# Epoch 13/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.2042 - acc: 0.9472 - val_loss: 0.3997 - val_acc: 0.8684
# Epoch 14/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2012 - acc: 0.9482 - val_loss: 0.3850 - val_acc: 0.8734
# Epoch 15/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2028 - acc: 0.9468 - val_loss: 0.3955 - val_acc: 0.8714
# Epoch 16/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.1977 - acc: 0.9483 - val_loss: 0.4037 - val_acc: 0.8695
# Epoch 17/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.1930 - acc: 0.9513 - val_loss: 0.5484 - val_acc: 0.8310
# Epoch 18/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1961 - acc: 0.9486 - val_loss: 0.4067 - val_acc: 0.8694
# Epoch 19/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1919 - acc: 0.9518 - val_loss: 0.4459 - val_acc: 0.8589
# Epoch 20/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1890 - acc: 0.9519 - val_loss: 0.4114 - val_acc: 0.8694

# %% [markdown]
# #### 시각화
# - Model 1은 **모델의 크기 축소**파트에서의 모델

# %%
l2_model_val_loss = l2_model_hist.history['val_loss']

epochs = range(1, 21)

plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, l2_model_val_loss, 'bo', label="Model L2-regularized")
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

# %% [markdown]
# #### L1과 비교

# %%
l1_model = Sequential([Dense(16, kernel_regularizer=l1(0.0001), activation='relu', input_shape=(10000, )),
                       Dense(16, kernel_regularizer=l1(0.0001), activation='relu'),
                       Dense(1, activation='sigmoid')])

l1_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['acc'])

l1_model.summary()
plot_model(l1_model, show_shapes=True)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 16)                160016
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
#튀는거(=overfitting) 잡아줌
l1_model_hist = l1_model.fit(x_train, y_train,
                             epochs=20,
                             batch_size=512,
                             validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 2s 39ms/step - loss: 0.5704 - acc: 0.8070 - val_loss: 0.4374 - val_acc: 0.8777
# Epoch 2/20
# 49/49 [==============================] - 1s 27ms/step - loss: 0.3824 - acc: 0.8926 - val_loss: 0.3734 - val_acc: 0.8889
# Epoch 3/20
# 49/49 [==============================] - 1s 27ms/step - loss: 0.3402 - acc: 0.9030 - val_loss: 0.3613 - val_acc: 0.8879
# Epoch 4/20
# 49/49 [==============================] - 1s 27ms/step - loss: 0.3220 - acc: 0.9077 - val_loss: 0.3648 - val_acc: 0.8844
# Epoch 5/20
# 49/49 [==============================] - 1s 27ms/step - loss: 0.3115 - acc: 0.9128 - val_loss: 0.3639 - val_acc: 0.8854
# Epoch 6/20
# 49/49 [==============================] - 1s 27ms/step - loss: 0.3062 - acc: 0.9134 - val_loss: 0.3630 - val_acc: 0.8861
# Epoch 7/20
# 49/49 [==============================] - 1s 27ms/step - loss: 0.3017 - acc: 0.9157 - val_loss: 0.3716 - val_acc: 0.8814
# Epoch 8/20
# 49/49 [==============================] - 1s 28ms/step - loss: 0.2936 - acc: 0.9194 - val_loss: 0.3646 - val_acc: 0.8854
# Epoch 9/20
# 49/49 [==============================] - 1s 27ms/step - loss: 0.2877 - acc: 0.9222 - val_loss: 0.3718 - val_acc: 0.8826
# Epoch 10/20
# 49/49 [==============================] - 1s 28ms/step - loss: 0.2833 - acc: 0.9248 - val_loss: 0.4201 - val_acc: 0.8630
# Epoch 11/20
# 49/49 [==============================] - 1s 27ms/step - loss: 0.2813 - acc: 0.9259 - val_loss: 0.4042 - val_acc: 0.8726
# Epoch 12/20
# 49/49 [==============================] - 1s 28ms/step - loss: 0.2765 - acc: 0.9272 - val_loss: 0.3857 - val_acc: 0.8800
# Epoch 13/20
# 49/49 [==============================] - 1s 27ms/step - loss: 0.2747 - acc: 0.9270 - val_loss: 0.3833 - val_acc: 0.8806
# Epoch 14/20
# 49/49 [==============================] - 1s 28ms/step - loss: 0.2689 - acc: 0.9300 - val_loss: 0.4036 - val_acc: 0.8710
# Epoch 15/20
# 49/49 [==============================] - 1s 28ms/step - loss: 0.2598 - acc: 0.9353 - val_loss: 0.3877 - val_acc: 0.8794
# Epoch 16/20
# 49/49 [==============================] - 1s 28ms/step - loss: 0.2621 - acc: 0.9328 - val_loss: 0.3877 - val_acc: 0.8807
# Epoch 17/20
# 49/49 [==============================] - 1s 27ms/step - loss: 0.2573 - acc: 0.9353 - val_loss: 0.3949 - val_acc: 0.8786
# Epoch 18/20
# 49/49 [==============================] - 1s 28ms/step - loss: 0.2512 - acc: 0.9368 - val_loss: 0.3924 - val_acc: 0.8791
# Epoch 19/20
# 49/49 [==============================] - 1s 28ms/step - loss: 0.2484 - acc: 0.9398 - val_loss: 0.4108 - val_acc: 0.8737
# Epoch 20/20
# 49/49 [==============================] - 1s 28ms/step - loss: 0.2430 - acc: 0.9418 - val_loss: 0.4436 - val_acc: 0.8631

# %%
l1_model_val_loss = l1_model_hist.history['val_loss']

epochs = range(1, 21)

plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, l1_model_val_loss, 'bo', label="Model L1-regularized")
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

# %% [markdown]
# 3가지 모델 비교
# - Original
# - L1
# - L2

# %%
l1_model_val_loss = l1_model_hist.history['val_loss']

epochs = range(1, 21)
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, l1_model_val_loss, 'bo', label="Model L1-regularized")
plt.plot(epochs, l2_model_val_loss, 'g--', label="Model L2-regularized")

plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

# %% [markdown]
# #### L1, L2와 비교

# %%
l1_l2_model = Sequential([Dense(16, kernel_regularizer=l1_l2(l1=0.0001, l2=0.0001),
                               activation='relu', input_shape=(10000, )),
                        Dense(16, kernel_regularizer=l1_l2(l1=0.0001, l2=0.0001),
                               activation='relu'),
                        Dense(1, activation='sigmoid')])

l1_l2_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['acc'])

l1_l2_model.summary()
plot_model(l1_l2model, show_shapes=True)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 16)                160016
# _________________________________________________________________
# dense_20 (Dense)             (None, 16)                272
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
l1_l2_model_hist = l1_l2_model.fit(x_train, y_train,
                             epochs=20,
                             batch_size=512,
                             validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 2s 36ms/step - loss: 0.5826 - acc: 0.8064 - val_loss: 0.4454 - val_acc: 0.8741
# Epoch 2/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.3888 - acc: 0.8892 - val_loss: 0.3765 - val_acc: 0.8875
# Epoch 3/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.3407 - acc: 0.9020 - val_loss: 0.3760 - val_acc: 0.8775
# Epoch 4/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.3242 - acc: 0.9065 - val_loss: 0.3581 - val_acc: 0.8880
# Epoch 5/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.3135 - acc: 0.9118 - val_loss: 0.3601 - val_acc: 0.8864
# Epoch 6/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.3098 - acc: 0.9124 - val_loss: 0.3647 - val_acc: 0.8838
# Epoch 7/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.3023 - acc: 0.9169 - val_loss: 0.3931 - val_acc: 0.8762
# Epoch 8/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.3010 - acc: 0.9174 - val_loss: 0.3726 - val_acc: 0.8828
# Epoch 9/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2938 - acc: 0.9201 - val_loss: 0.3771 - val_acc: 0.8812
# Epoch 10/20
# 49/49 [==============================] - 1s 25ms/step - loss: 0.2919 - acc: 0.9208 - val_loss: 0.3823 - val_acc: 0.8798
# Epoch 11/20
# 49/49 [==============================] - 1s 25ms/step - loss: 0.2873 - acc: 0.9244 - val_loss: 0.3873 - val_acc: 0.8764
# Epoch 12/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2821 - acc: 0.9246 - val_loss: 0.3767 - val_acc: 0.8835
# Epoch 13/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2819 - acc: 0.9250 - val_loss: 0.3784 - val_acc: 0.8822
# Epoch 14/20
# 49/49 [==============================] - 1s 25ms/step - loss: 0.2751 - acc: 0.9272 - val_loss: 0.4102 - val_acc: 0.8718
# Epoch 15/20
# 49/49 [==============================] - 1s 25ms/step - loss: 0.2746 - acc: 0.9271 - val_loss: 0.3863 - val_acc: 0.8807
# Epoch 16/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2659 - acc: 0.9326 - val_loss: 0.3863 - val_acc: 0.8804
# Epoch 17/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2619 - acc: 0.9348 - val_loss: 0.4020 - val_acc: 0.8759
# Epoch 18/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2585 - acc: 0.9346 - val_loss: 0.4043 - val_acc: 0.8715
# Epoch 19/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2521 - acc: 0.9383 - val_loss: 0.3925 - val_acc: 0.8769
# Epoch 20/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.2484 - acc: 0.9390 - val_loss: 0.3941 - val_acc: 0.8777

# %% [markdown]
# 4가지 모델 비교
# - Original
#
# - L1
#
# - L2
#
# - L1_L2

# %%
l1_l2_model_val_loss = l1_l2_model_hist.history['val_loss']

epochs = range(1, 21)
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, l1_model_val_loss, 'bo', label="Model L1-regularized")
plt.plot(epochs, l2_model_val_loss, 'g--', label="Model L2-regularized")
plt.plot(epochs, l1_l2_model_val_loss, 'ko', label="Model L1_l2-regularized")


plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()

# %% [markdown]
# ### 드롭아웃(Dropout)
# - 신경망을 위해 사용되는 규제 기법 중 가장 효과적이고 널리 사용되는 방법
#
# - 신경망의 레이어에 드롭아웃을 적용하면 훈련하는 동안 무작위로 층의 일부 특성(노드)를 제외
#   - 예를 들어, [1.0, 3.2, 0.6, 0.8, 1.1] 라는 벡터에 대해 드롭아웃을 적용하면 **무작위로 0으로 바뀜**
#     $\rightarrow$ [0, 3.2, 0.6, 0.8, 0]
#
#   - 보통 0.2 ~ 0.5 사이의 비율로 지정됨
#
# - 테스트 단계에서는 그 어떤 노드도 드롭아웃 되지 않는다.
#   - 대신 해당 레이어의 출력 노드를 드롭아웃 비율에 맞게 줄여줌

# %%
from tensorflow.keras.layers import Dropout
from tensorflow.keras.utils import plot_model

# %% [markdown]
# #### 모델 구성

# %%
dropout_model = Sequential([Dense(16, activation='relu', input_shape=(10000, )),
                          Dropout(0.5),
                          Dense(16, activation='relu'),
                          Dropout(0.5),
                          Dense(1, activation='sigmoid')])

dropout_model.compile(optimizer='rmsprop',
                 loss='binary_crossentropy',
                 metrics=['acc'])

dropout_model.summary()
plot_model(dropout_model, show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16)                160016
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### 모델 학습

# %%
dropout_model_hist = dropout_model.fit(x_train, y_train,
                             epochs=20,
                             batch_size=512,
                             validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 49/49 [==============================] - 5s 34ms/step - loss: 0.5991 - acc: 0.6825 - val_loss: 0.4619 - val_acc: 0.8656
# Epoch 2/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.4513 - acc: 0.8126 - val_loss: 0.3410 - val_acc: 0.8829
# Epoch 3/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.3641 - acc: 0.8621 - val_loss: 0.2992 - val_acc: 0.8855
# Epoch 4/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.3015 - acc: 0.8936 - val_loss: 0.2764 - val_acc: 0.8905
# Epoch 5/20
# 49/49 [==============================] - 1s 28ms/step - loss: 0.2624 - acc: 0.9104 - val_loss: 0.2778 - val_acc: 0.8900
# Epoch 6/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.2343 - acc: 0.9241 - val_loss: 0.2843 - val_acc: 0.8879
# Epoch 7/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.2085 - acc: 0.9317 - val_loss: 0.3111 - val_acc: 0.8873
# Epoch 8/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1949 - acc: 0.9378 - val_loss: 0.3151 - val_acc: 0.8847
# Epoch 9/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1794 - acc: 0.9432 - val_loss: 0.3424 - val_acc: 0.8831
# Epoch 10/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1627 - acc: 0.9466 - val_loss: 0.3636 - val_acc: 0.8840
# Epoch 11/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1531 - acc: 0.9493 - val_loss: 0.3792 - val_acc: 0.8805
# Epoch 12/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1459 - acc: 0.9538 - val_loss: 0.4023 - val_acc: 0.8812
# Epoch 13/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1340 - acc: 0.9566 - val_loss: 0.4377 - val_acc: 0.8784
# Epoch 14/20
# 49/49 [==============================] - 1s 24ms/step - loss: 0.1272 - acc: 0.9587 - val_loss: 0.4582 - val_acc: 0.8762
# Epoch 15/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1249 - acc: 0.9595 - val_loss: 0.4717 - val_acc: 0.8765
# Epoch 16/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1208 - acc: 0.9616 - val_loss: 0.4819 - val_acc: 0.8752
# Epoch 17/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1173 - acc: 0.9626 - val_loss: 0.5122 - val_acc: 0.8745
# Epoch 18/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1114 - acc: 0.9641 - val_loss: 0.5303 - val_acc: 0.8746
# Epoch 19/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1096 - acc: 0.9647 - val_loss: 0.5621 - val_acc: 0.8723
# Epoch 20/20
# 49/49 [==============================] - 1s 23ms/step - loss: 0.1068 - acc: 0.9652 - val_loss: 0.5756 - val_acc: 0.8699

# %% [markdown]
# #### 시각화

# %%
dropout_model_val_loss = dropout_model_hist.history['val_loss']

epochs = range(1, 21)
plt.plot(epochs, model_1_val_loss, 'r+', label='Model 1')
plt.plot(epochs, dropout_model_val_loss, 'co', label="Model Dropout")
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.legend()
plt.grid()
